# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri):\n    \"\"\"\n    Extract the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): S3 URI in the format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        str: The bucket name, or None if the URI is invalid\n    \"\"\"\n    if not s3_uri:\n        return None\n    \n    # Remove the s3:// prefix\n    if s3_uri.startswith('s3://'):\n        s3_uri = s3_uri[5:]\n    else:\n        return None\n    \n    # Split by '/' and get the first part (bucket name)\n    parts = s3_uri.split('/')\n    bucket_name = parts[0]\n    \n    return bucket_name if bucket_name else None\n\n\n# Test cases\ntest_cases = [\n    's3://my-bucket/path/to/file.txt',\n    's3://another-bucket/file.txt',\n    's3://bucket123/folder/subfolder/file.json',\n    's3://my-bucket/',\n    's3://my-bucket',\n    'invalid-uri',\n    's3://',\n]\n\nfor uri in test_cases:\n    result = parse_s3_bucket_name(uri)\n    print(f\"URI: {uri:45} -> Bucket: {result}\")\n```\n\n**Output:**\n```\nURI: s3://my-bucket/path/to/file.txt         -> Bucket: my-bucket\nURI: s3://another-bucket/file.txt            -> Bucket: another-bucket\nURI: s3://bucket123/folder/subfolder/file.json -> Bucket: bucket123\nURI: s3://my-bucket/                         -> Bucket: my-bucket\nURI: s3://my-bucket                          -> Bucket: my-bucket\nURI: invalid-uri                             -> Bucket: None\nURI: s3://                                    -> Bucket: None\n```\n\n## Alternative Solutions\n\n### Using Regular Expressions (Regex)\n```python\nimport re\n\ndef parse_s3_bucket_name_regex(s3_uri):\n    \"\"\"Extract bucket name using regex.\"\"\"\n    match = re.match(r's3://([a-zA-Z0-9._-]+)', s3_uri)\n    return match.group(1) if match else None\n```\n\n### Using urllib.parse\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name_urllib(s3_uri):\n    \"\"\"Extract bucket name using urllib.\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc if parsed.scheme == 's3' else None\n```\n\nAll three approaches work well. Choose based on your needs:\n- **Simple string split**: Most readable for basic use cases\n- **Regex**: Best for validation against S3 naming rules\n- **urllib**: Best if you need to parse multiple components of the URI",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract only the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution is practical and covers multiple approaches well, but lacks proper S3 bucket name validation. AWS S3 has specific naming requirements that should be enforced when parsing. The urllib approach is technically superior but is presented as a tertiary option rather than the recommended solution. While the code works for basic cases, it would accept invalid bucket names without complaint, which could lead to runtime errors downstream."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template Snippet\n\nHere's a JSON CloudFormation template snippet that defines an AWS Lambda function with basic properties:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template with AWS Lambda function\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"my-lambda-function\",\n        \"Runtime\": \"python3.11\",\n        \"Handler\": \"index.lambda_handler\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"MyLambdaFunction\"\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n| Property | Description |\n|----------|-------------|\n| **FunctionName** | The logical name of the Lambda function (`my-lambda-function`) |\n| **Runtime** | The execution environment (`python3.11`, `nodejs18.x`, `java11`, etc.) |\n| **Handler** | Entry point in format `filename.function_name` (`index.lambda_handler`) |\n| **Role** | IAM role ARN that Lambda assumes when executing |\n| **Code** | Either inline code (`ZipFile`) or S3 reference (`S3Bucket`/`S3Key`) |\n\n## Alternative: Using S3 for Code\n\nIf your Lambda code is stored in S3:\n\n```json\n\"Code\": {\n  \"S3Bucket\": \"my-code-bucket\",\n  \"S3Key\": \"lambda-function.zip\"\n}\n```\n\n## Alternative Runtimes:\n\n- `nodejs18.x`\n- `python3.10`\n- `java11`\n- `dotnet6`\n- `go1.x`\n\nThis template includes a basic IAM role and outputs the Lambda function's ARN and name for reference.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS Lambda function with basic properties (function name, runtime, handler, and role ARN)",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution is technically sound and production-ready, but over-engineers the requirements. While the extra components (IAM role, outputs, code) demonstrate AWS knowledge and best practices, they diverge from the specific ask of a 'snippet' with just the four basic properties. A minimal solution focusing on the AWS::Lambda::Function resource with those core properties would have been more appropriate, though this version is more practically useful. The quality of documentation and examples partially compensates for scope creep."
#   },
#   {
#     "output": "# AWS IAM Policy Wildcard Detector\n\nHere's a Python function that checks for wildcard resource permissions in an AWS IAM policy:\n\n```python\nimport json\nfrom typing import Union\n\ndef has_wildcard_resources(policy_json: str) -> bool:\n    \"\"\"\n    Check if an AWS IAM policy contains any wildcard ('*') resource permissions.\n    \n    Args:\n        policy_json: A JSON string representing an AWS IAM policy\n        \n    Returns:\n        True if the policy contains any wildcard ('*') resources, False otherwise\n        \n    Raises:\n        json.JSONDecodeError: If the input is not valid JSON\n        TypeError: If the input is not a string\n    \"\"\"\n    if not isinstance(policy_json, str):\n        raise TypeError(\"Input must be a JSON string\")\n    \n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError as e:\n        raise json.JSONDecodeError(f\"Invalid JSON: {e.msg}\", e.doc, e.pos)\n    \n    # Get the Statement array from the policy\n    statements = policy.get(\"Statement\", [])\n    \n    if not isinstance(statements, list):\n        return False\n    \n    # Check each statement for wildcard resources\n    for statement in statements:\n        if not isinstance(statement, dict):\n            continue\n            \n        resources = statement.get(\"Resource\", [])\n        \n        # Normalize resources to a list\n        if isinstance(resources, str):\n            resources = [resources]\n        elif not isinstance(resources, list):\n            continue\n        \n        # Check if any resource is a wildcard\n        for resource in resources:\n            if resource == \"*\":\n                return True\n    \n    return False\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: Policy with wildcard resource\n    policy_with_wildcard = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    '''\n    print(\"Test 1 (Wildcard resource):\", has_wildcard_resources(policy_with_wildcard))\n    # Expected: True\n    \n    # Test 2: Policy without wildcard resource\n    policy_without_wildcard = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    '''\n    print(\"Test 2 (No wildcard resource):\", has_wildcard_resources(policy_without_wildcard))\n    # Expected: False\n    \n    # Test 3: Policy with multiple resources (one is wildcard)\n    policy_multiple_resources = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:*\",\n                \"Resource\": [\n                    \"arn:aws:s3:::my-bucket\",\n                    \"*\"\n                ]\n            }\n        ]\n    }\n    '''\n    print(\"Test 3 (Multiple resources with wildcard):\", has_wildcard_resources(policy_multiple_resources))\n    # Expected: True\n    \n    # Test 4: Policy with multiple statements (one has wildcard)\n    policy_multiple_statements = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"ec2:DescribeInstances\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    '''\n    print(\"Test 4 (Multiple statements with wildcard):\", has_wildcard_resources(policy_multiple_statements))\n    # Expected:",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy JSON string as input and returns True if it contains any wildcard ('*') resource permissions, False otherwise",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution successfully solves the stated problem of detecting full wildcard ('*') resources. The code is robust with proper error handling and readable. However, it has a minor presentation issue (incomplete test comment) and doesn't address broader security considerations like partial wildcards or alternative permission structures. For the specific task as written, it works correctly, but real-world AWS security scanning might need broader pattern matching."
#   }
# ]
